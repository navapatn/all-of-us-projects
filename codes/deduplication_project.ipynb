# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import re
from collections import Counter
import openai
import ast


def deduplicate_csv(csv_path, columns, similarity_threshold=0.80):
    df = pd.read_csv(csv_path)

    df['combined_text'] = df[columns].fillna('').agg(' '.join, axis=1)

    # Create the TF-IDF matrix
    vectorizer = TfidfVectorizer()
    tfidf_matrix = vectorizer.fit_transform(df['combined_text'])

    # Calculate the cosine similarity matrix
    cosine_sim = cosine_similarity(tfidf_matrix)

    # Find duplicates: records with similarity above the threshold
    duplicates_indices = set()
    for i in range(cosine_sim.shape[0]):
        for j in range(i+1, cosine_sim.shape[0]):
            if cosine_sim[i, j] > similarity_threshold:
                # Choose one of the duplicates to drop, e.g., the one with the higher index
                duplicates_indices.add(max(i, j))

    # Drop the duplicates and reset the index
    df_deduplicated = df.drop(index=duplicates_indices).reset_index(drop=True)

    return df_deduplicated

# Specify the path to your CSV file and which columns to consider for deduplication
csv_file_path = 'projects_output_diabetes_combined.csv'
columns_to_consider = ['title', 'main_goal_and_aims']

# Load the dataset
df = pd.read_csv(csv_file_path)
print(f"Number of records before deduplication: {df.shape[0]}")

# Perform deduplication
df_deduplicated = deduplicate_csv(csv_file_path, columns_to_consider)
print(f"Number of records after deduplication: {df_deduplicated.shape[0]}")

# Save the deduplicated dataframe to a new CSV file
df_deduplicated.to_csv('deduplicated_projects_output.csv', index=False)
# Out:
# Number of records before deduplication: 573
# Number of records after deduplication: 407

# %%
df = pd.read_csv(csv_file_path)
print(df.columns.tolist())
# Out:
# ['title', 'main_goal_and_aims', 'Questions', 'Purpose', 'Approaches', 'Findings', 'Categories', 'DataTier', 'Team']

# %%
def extract_team_info(team_text):
    team_members = [member.strip() for member in team_text.split('-') if member.strip()]
    individuals = []
    institutions = []
    for member in team_members:
        parts = member.rsplit(',', 1)
        name = parts[0].strip()
        institution = parts[1].strip() if len(parts) > 1 else None
        individuals.append(name)
        if institution:
            institutions.append(institution)
    return individuals, institutions

def calculate_team_metrics(df):
    all_individuals = []
    all_institutions = []
    multi_institutional_count = 0

    for team_text in df['Team']:
        individuals, institutions = extract_team_info(team_text)
        all_individuals.extend(individuals)
        all_institutions.extend(institutions)
        if len(set(institutions)) > 1:
            multi_institutional_count += 1

    unique_individuals = len(set(all_individuals))
    unique_institutions = len(set(all_institutions))
    avg_individuals_per_team = len(all_individuals) / len(df)
    multi_institutional_percentage = (multi_institutional_count / len(df)) * 100

    return unique_individuals, unique_institutions, avg_individuals_per_team, multi_institutional_percentage

def calculate_category_metrics(df):
    demographic_category_count = 0
    for categories in df['Categories']:
        if "This study will not center on underrepresented populations." not in categories:
            demographic_category_count += 1
    percentage_with_demographic = (demographic_category_count / len(df)) * 100
    return percentage_with_demographic

# Load the deduplicated data
df = pd.read_csv('deduplicated_projects_output.csv')  # Replace with the actual path to the deduplicated CSV

# Calculate metrics related to the team
unique_individuals, unique_institutions, avg_individuals_per_team, multi_institutional_percentage = calculate_team_metrics(df)

# Calculate metrics related to the categories
percentage_with_demographic = calculate_category_metrics(df)

# Print the metrics
print(f"# of registered projects (deduplicated): {len(df)}")
#print(f"# of unique individuals listed as team-members: {unique_individuals}")
#print(f"Average number of individuals per team: {avg_individuals_per_team:.2f}")
print(f"% projects using demographic categories for study: {percentage_with_demographic:.2f}%")
#print(f"# of unique institutions: {unique_institutions}")
#print(f"% projects with multi-institutional teams: {multi_institutional_percentage:.2f}%")
# Out:
# # of registered projects (deduplicated): 407
# % projects using demographic categories for study: 51.84%

# %%
df = pd.read_csv('deduplicated_projects_output.csv')


sample_df = df

openai.api_key = ''
model = "gpt-3.5-turbo-0125"

results = []
for index, row in sample_df.iterrows():
    prompt = (
        'Given the team information, I want you to extract individual names, roles, and institutions '
        'and return the information in three separate Python lists.\n\n'
        'Example 1:\n'
        'Team information: \"Research Team Owner: Elizabeth Theusch - Other, University of California, San Francisco\"\n'
        '1. ["Owner"]\n'
        '2. ["Elizabeth Theusch"]\n'
        '3. ["University of California, San Francisco"]\n\n'
        'Example 2:\n'
        'Team information: \"Research Team Owner: Xinyi Tan - Graduate Trainee, Columbia University '
        'Jay Lusk - Research Fellow, Duke University\"\n'
        '1. ["Owner", "Graduate Trainee", "Research Fellow"]\n'
        '2. ["Xinyi Tan", "Jay Lusk"]\n'
        '3. ["Columbia University", "Duke University"]\n\n'
        'Now, extract the individual names, roles, and institutions from the following team information as three Python lists:\n'
        f"{row['Team']}\n"
    )
    messages = [{"role": "system", "content": "Extract the individual names, roles, and institutions. Follow the format in the prompt strictly"},
                {"role": "user", "content": prompt }]
    try:
        response = openai.chat.completions.create(
            model="gpt-3.5-turbo",
            messages=messages
        )
        extracted_info = response.choices[0].message.content
        results.append(extracted_info)
        #print(f"Original: {row['Team']}\nExtracted: {extracted_info}\n")
        #print(f"Extracted: {extracted_info}\n")
    except openai.OpenAIError as e:
        print(f"An error occurred: {e}")
        results.append(None)




sample_df['Extracted Team Info'] = results
sample_df.to_csv('extracted_team_info_sample.csv', index=False)

# %%
def clean_and_parse(info):
    info = (info.replace('Roles:', '')
               .replace('Names:', '')
               .replace('Institutions:', '')
               .replace('1. ', '')
               .replace('2. ', '')
               .replace('3. ', '')
               .replace('Roles List:','')
               .replace('Names List:','')
               .replace('Institutions List:','')
               )

    print(info)
    try:

        parts = [part.strip() for part in info.split('\n') if part.strip()]

        roles = ast.literal_eval(parts[0])
        researchers = ast.literal_eval(parts[1])
        institutions = ast.literal_eval(parts[2])
        return roles, researchers, institutions
    except Exception as e:
        print(f"An error occurred while parsing: {e}")
        return [], [], []


extracted_team = pd.read_csv('extracted_team_info_sample.csv')

parsed_results = []
for index, row in extracted_team.iterrows():
    roles, researchers, institutions = clean_and_parse(row['Extracted Team Info'])
    parsed_results.append({
        'Roles': roles,
        'Researchers': researchers,
        'Institutions': institutions
    })


df_parsed = pd.DataFrame(parsed_results)


df_parsed.to_csv('parsed_results.csv', index=False)


df_parsed.head()
# Out:
# ["Owner", "Research Fellow"]
# ["Sarada Ghosh"]
# ["Cornell University"]
# ["Owner", "Graduate Trainee", "Research Fellow"]
# ["Xinyi Tan", "Jay Lusk"]
# ["Columbia University", "Duke University"]
# ["Owner", "Collaborator"]
# ["Reagan Ballard", "Micah Hysong"]
# ["University of North Carolina, Chapel Hill", "University of North Carolina, Chapel Hill"]
#  ["Robin Beaumont", "Michael Weedon", "Gareth Hawkes", "Andrew Wood", "Harry Wright", "Harry Green"]
#  ["Research Fellow", "Senior Researcher", "Research Fellow", "Mid-career Tenured Researcher", "Research Assistant", "Mid-career Tenured Researcher"]
#  ["University of Exeter", "University of Exeter", "University of Exeter", "University of Exeter", "University of Exeter", "University of Exeter"]
# ["Owner", "Project Personnel"]
# ["Yuji Choi"]
# ["Johns Hopkins University"]
# ["Owner", "Collaborator", "Collaborator"]
# ["Jonathon Baccus", "Hui Wang", "Graham Jones"]
# ["University of Alabama", "University of Alabama", "University of Alabama"]
# ["Owner", "Graduate Trainee"]
# ["Tadesse Abegaz"]
# ["Florida A&M University"]
# ["Owner", "Research Fellow"]
# ["Omar Costilla Reyes"]
# ["Massachusetts Institute of Technology"]
# ["Owner", "Research Fellow", "Senior Researcher", "Research Assistant", "Research Fellow"]
# ["Robin Beaumont", "Michael Weedon", "Harry Wright", "Gareth Hawkes"]
# ["University of Exeter", "University of Exeter", "University of Exeter", "University of Exeter"]
# ["Owner", "Graduate Trainee", "Mid-career Tenured Researcher"]
# ["Pianhong Han", "Esther Black"]
# ["University of Kentucky", "University of Kentucky"]
# ["Owner", "Research Fellow", "Research Fellow", "Research Fellow", "Graduate Trainee"]
# ["Srishti Sinha", "Samantha Huey", "Sarada Ghosh", "Naiwen Ji"]
# ["Cornell University", "Cornell University", "Cornell University", "Cornell University"]
# ["Owner", "Owner", "Collaborator", "Collaborator", "Collaborator", "Collaborator", "Collaborator", "Collaborator", "Collaborator", "Collaborator", "Collaborator", "Collaborator", "Collaborator", "Collaborator", "Collaborator", "Collaborator"]
# ["Kaavya Ashok", "Alisa Manning", "Ravi Mandla", "Raymond Kreienkamp", "Lukasz Szczerbinski", "Sara Cromer", "Reagan Ballard", "Laura Raffield", "Miriam Udler", "Micah Hysong", "Josephine Li", "Josep Mercader", "Gareth Hawkes", "Alicia Huerta", "Aaron Deutsch", "Alexandra Barry"]
# ["Broad Institute", "Mass General Brigham", "Broad Institute", "Broad Institute", "Broad Institute", "Mass General Brigham", "University of North Carolina, Chapel Hill", "University of North Carolina, Chapel Hill", "Broad Institute", "University of North Carolina, Chapel Hill", "Mass General Brigham", "Broad Institute", "University of Exeter", "Broad Institute", "Mass General Brigham", "Mass General Brigham"]
# ["Owner", "Senior Researcher", "Undergraduate Student"]
# ["Andrew Magis", "Lea Repovic"]
# ["Institute for Systems Biology", "Institute for Systems Biology"]
# ["Owner"]
# ["Scott Jones"]
# ["Northwell Health"]
# ["Owner", "Project Personnel", "Early Career Tenure-track Researcher"]
# ["Zhirui Deng", "Theresa Koleck", "Caitlin Dreisbach", "Carol Li"]
# ["University of Pittsburgh", "University of Pittsburgh", "University of Rochester", "University of Rochester"]
# ["Owner"]
# ["Peixian Dong"]
# ["University of Southern California"]
# ["Owner", "Graduate Trainee", "Other"]
# ["Daniel Flores", "Andy Lee"]
# ["University of California, Irvine", "University of California, Irvine"]
# ["Owner", "Graduate Trainee"]
# ["Junjie Lu"]
# ["Stanford University"]
# ["Owner", "Early Career Tenure-track Researcher", "Early Career Tenure-track Researcher", "Mid-career Tenured Researcher", "Mid-career Tenured Researcher", "Early Career Tenure-track Researcher"]
# ["Veronica Brady", "Nyasha Chambwe", "German Rosas-Acosta", "Anjana Saxena", "Anna Eiring"]
# ["University of Texas Health Science Center, Houston", "Feinstein Institute for Medical Research", "University of Texas at El Paso", "City University of New York (CUNY)", "Texas Tech University Health Sciences Center at El Paso"]
# ["Owner", "Research Fellow"]
# ["Yangyang Deng"]
# ["National Institutes of Health (NIH)"]
# ["Owner", "Research Fellow"]
# ["Mai Sedki"]
# ["Stanford University"]
#  ["Owner", "Graduate Trainee", "Collaborator", "Collaborator", "Collaborator"]
#  ["Ahmed Khattab", "Shang-Fu Chen", "Aidan Cardall", "Aidan Cardall", "Justin Wang"]
#  ["Scripps Research", "Scripps Research", "Brigham Young University", "Scripps Research", "Scripps Research"]
# ['Owner', 'Collaborators', 'Collaborators', 'Collaborators', 'Collaborators', 'Collaborators', 'Collaborators']
# ['Tennille Leak-Johnson', 'Viviane Schuch', 'Muhammed Idris', 'Jade Avery', 'Hannah Luk', 'Deyana Lewis', 'Ariel Williams']
# ['Morehouse School of Medicine', 'Morehouse School of Medicine', 'Morehouse School of Medicine', 'Morehouse School of Medicine', 'University of Texas Medical Branch (UTMB) at Galveston', 'Morehouse School of Medicine', 'National Human Genome Research Institute (NIH - NHGRI)']
# ["Owner", "Collaborators"]
# ["Chamika Hawkins-Taylor", "Xiao Zhang", "Hongyan Xu"]
# ["Xavier University of Louisiana", "Xavier University of Louisiana", "Augusta University"]
# ["Owner"]
# ["Fan Li"]
# ["University of Missouri"]
# ["Owner", "Graduate Trainee"]
# ["Tadesse Abegaz", "Tadesse Abegaz"]
# ["Florida A&M University", "Florida A&M University"]
# ["Owner", "Graduate Trainee", "Collaborator"]
# ["Jordan Keels", "Theresa Koleck"]
# ["Boston College", "University of Pittsburgh"]
# ["Owner", "Graduate Trainee"]
# ["Megana Thamilselvan"]
# ["University of Toronto"]
# ["Owner", "Undergraduate Student", "Undergraduate Student", "Undergraduate Student"]
# ["Jesus Leyva", "Colin Hooppaw", "Cayla Hollingsworth"]
# ["Arizona State University", "Arizona State University", "Arizona State University"]
# ["Owner", "Senior Researcher"]
# ["Amelie Bonnefond"]
# ["Inserm"]
# ["Owner", "Graduate Trainee"]
# ["Shivam Sharma"]
# ["Georgia Institute of Technology"]
#
# ["Owner", "Graduate Trainee", "Graduate Trainee", "Graduate Trainee", "Graduate Trainee"]
#
#
# ["YALIN LI", "SREE SAI SREEVANI GONGALREDDY", "niharika sarraf", "Bhargava Cherukuri"]
#
#
# ["George Mason University", "George Mason University", "George Mason University", "George Mason University"]
# ['Owner', 'Undergraduate Student', 'Project Personnel', 'Undergraduate Student', 'Research Associate']
# ['Dafeng Hui', 'Takara Pierce', 'Stefanee Tillman', 'Sarena Noel', 'Javan Carter']
# ['Fisk University', 'Tennessee State University', 'All of Us Researcher Academy/RTI International', 'Tennessee State University', 'All of Us Researcher Academy/RTI International']
# ["Owner"]
# ["Jessica Rast"]
# ["Drexel University"]
# ["Owner", "Collaborator"]
# ["Tess Cherlin", "Katie Cardone"]
# ["University of Pennsylvania", "University of Pennsylvania"]
#
# ["Josep Mercader", "Casey Marchek", "Alisa Manning", "Ravi Mandla", "Philip Schroeder", "Miriam Udler", "Maheak Vora", "Lukasz Szczerbinski", "Josephine Li", "Bianca Porneala", "Kaavya Ashok", "Aaron Deutsch", "Satoshi Yoshiji", "Qixuan Jin", "Maggie Ng", "Yingchang Lu", "Joohyun Kim", "Haoran Zhang", "Alicia Huerta"]
#
#
# ["Early Career Tenure-track Researcher", "Project Personnel", "Early Career Tenure-track Researcher", "Project Personnel", "Project Personnel", "Early Career Tenure-track Researcher", "Project Personnel", "Research Fellow", "Early Career Tenure-track Researcher", "Project Personnel", "Early Career Tenure-track Researcher", "Research Fellow", "Research Fellow", "Graduate Trainee", "Mid-career Tenured Researcher", "Early Career Tenure-track Researcher", "Other", "Graduate Trainee", "Research Fellow"]
#
#
# ["Broad Institute", "Mass General Brigham", "Mass General Brigham", "Broad Institute", "Broad Institute", "Broad Institute", "Broad Institute", "Broad Institute", "Mass General Brigham", "Mass General Brigham", "Broad Institute", "Mass General Brigham", "Broad Institute", "Massachusetts Institute of Technology", "Vanderbilt University Medical Center", "Vanderbilt University Medical Center", "Vanderbilt University Medical Center", "Massachusetts Institute of Technology", "Broad Institute"]
# ["Owner", "Undergraduate Student"]
# ["Vaibhavi Sunkara"]
# ["University of Texas, San Antonio"]
# ["Owner", "Graduate Trainee", "Early Career Tenure-track Researcher"]
# ["Jade Avery", "Tennille Leak-Johnson"]
# ["Morehouse School of Medicine", "Morehouse School of Medicine"]
# ["Owner", "Collaborator", "Collaborator"]
# ["Jianhua Zhang", "Harrison McNabb", "Dayo Shittu"]
# ["National Institute of Diabetes and Digestive and Kidney Diseases (NIH - NIDDK)", "National Institute of Diabetes and Digestive and Kidney Diseases (NIH - NIDDK)", "National Human Genome Research Institute (NIH-NHGRI)"]
# ["Owner"]
# ["Centdrika Hurt"]
# ["Birmingham-Southern College"]
# ["Owner", "Mid-career Tenured Researcher", "Late Career Tenured Researcher", "Early Career Tenure-track Researcher"]
# ["Julie Volkman", "Ben Gerber", "Alicia Lamere"]
# ["Bryant University", "University of Massachusetts Medical School", "Stonehill College"]
# ["Owner", "Undergraduate Student"]
# ["William Navarrete Moreno"]
# ["University of Colorado, Denver"]
# ["Owner", "Undergraduate Student", "Research Fellow", "Research Assistant", "Graduate Trainee"]
# ["Jeff Kramer", "Vincent Lam", "Sonali Gupta", "Shivam Sharma"]
# ["Georgia Institute of Technology", "National Institutes of Health (NIH)", "National Institutes of Health (NIH)", "Georgia Institute of Technology"]
# ["Owner", "Graduate Trainee"]
# ["Matthew Alonso"]
# ["University of Miami"]
# ["Owner"]
# ["azene zenebe"]
# ["Bowie State University"]
# ["Owner", "Research Fellow", "Graduate Trainee", "Project Personnel", "Project Personnel", "Research Fellow", "Project Personnel", "Research Fellow", "Project Personnel"]
# ["Johanna Smith", "Kristjan Norland", "Yue Yu", "jie na", "Marwan Hamed", "Matt Kosel", "Ozan Dikilitas", "Jacob Petrzelka"]
# ["Mayo Clinic", "Mayo Clinic", "Mayo Clinic", "Mayo Clinic", "Mayo Clinic", "Mayo Clinic", "Mayo Clinic", "Mayo Clinic"]
# ["Owner", "Graduate Trainee"]
# ["Alexis Cenname"]
# ["University of Pittsburgh"]
# ["Owner", "Undergraduate Student", "Project Personnel"]
# ["Brandon Grover", "Mozhdeh Bahrainian"]
# ["University of Wisconsin, Madison"]
# ["Owner", "Graduate Trainee", "Collaborator", "Collaborator", "Collaborator"]
# ["Richard Mojica Velez", "Valeria Miranda", "Kyle Melin", "Jonathan Hernandez-Agosto", "Bianca  Torres"]
# ["University of Puerto Rico Medical Sciences", "University of Puerto Rico Medical Sciences", "University of Puerto Rico Medical Sciences", "University of Puerto Rico Medical Sciences", "University of Puerto Rico Medical Sciences"]
# ["Owner", "Collaborators"]
# ["Sijia Li", "Rui Duan", "Chongliang Luo"]
# ["Harvard T. H. Chan School of Public Health", "Washington University in St. Louis"]
# ["Owner", "Graduate Trainee"]
# ["Alexis Cunningham"]
# ["Meharry Medical College"]
# ["Owner", "Research Fellow"]
# ["Cassie Robertson"]
# ["National Human Genome Research Institute (NIH - NHGRI)"]
# ["Owner", "Graduate Trainee", "Research Fellow", "Graduate Trainee"]
# ["Lijia Zheng", "Olga Kravchenko", "Chenyu Li"]
# ["Stanford University", "University of Pittsburgh", "University of Pittsburgh"]
# ["Owner", "Early Career Tenure-track Researcher"]
# ["Anu Sharma"]
# ["University of Florida"]
# ["Owner", "Graduate Trainee"]
# ["Anna-Sophie Thein"]
# ["University of California, San Francisco"]
# ["Owner", "Research Fellow", "Early Career Tenure-track Researcher", "Senior Researcher"]
# ["Timothy Frayling", "Liza Darrous", "Lauric Ferrat", "Aurelie Kamoun"]
# ["Universite de Geneve", "Universite de Geneve", "Universite de Geneve", "Universite de Geneve"]
# ["Owner"]
# ["Seyedeh Neelufar Payrovnaziri"]
# ["University of California, Irvine"]
# ["Owner", "Graduate Trainee", "Project Personnel", "Other"]
# ["Chloe Bennett", "Robert Cavanaugh", "Louisa Smith"]
# ["Northeastern University", "Northeastern University", "Northeastern University"]
# ["Owner", "Undergraduate Student"]
# ["Vir Trivedi"]
# ["Loyola University Chicago"]
# ["Owner", "Project Personnel"]
# ["Scott Sauers"]
# ["Washington University in St. Louis"]
# ["Owner"]
# ["Rochelle Castillo"]
# ["Mass General Brigham"]
# ["Owner", "Research Assistant", "Graduate Trainee"]
# ["Sonali Gupta", "Onyinye Chukka"]
# ["National Institutes of Health (NIH)", "Georgia Institute of Technology"]
# ["Owner", "Graduate Trainee", "Graduate Trainee"]
# ["Shivam Sharma", "Courtney Astore"]
# ["Georgia Institute of Technology", "Georgia Institute of Technology"]
# ["Owner", "Project Personnel"]
# ["Lavanya Muthukumar"]
# ["University of Michigan"]
# ["Owner", "Project Personnel"]
# ["Michael Douglas"]
# ["University of California, San Francisco"]
# ["Owner", "Undergraduate Student", "Graduate Trainee", "Graduate Trainee"]
# ["Yang Yang", "Tian Liu", "Che-Yi Liao"]
# ["Georgia Institute of Technology", "Texas A&M University", "Georgia Institute of Technology"]
# ["Owner", "Other", "Early Career Tenure-track Researcher", "Other"]
# ["Izabelle Humes", "Kathryn Shows", "Aymone Kouame"]
# ["All of Us Program Operational Use", "Virginia State University", "All of Us Program Operational Use"]
# ["Owner", "Graduate Trainee", "Research Fellow", "Early Career Tenure-track Researcher"]
# ["Dara Brena", "Viviane Schuch", "Erica Johnson"]
# ["Morehouse School of Medicine", "Morehouse School of Medicine", "Morehouse School of Medicine"]
#
# ["Owner", "Graduate Trainee", "Graduate Trainee"]
#
#
# ["Lijia Zheng", "Chenyu Li"]
#
#
# ["Stanford University", "University of Pittsburgh"]
# ["Owner", "Project Personnel"]
# ["Marieke Jones"]
# ["University of Virginia"]
# ["Owner", "Project Personnel", "Research Fellow", "Research Assistant", "Graduate Trainee"]
# ["Nur Shahir", "Vincent Lam", "Sonali Gupta", "Shivam Sharma"]
# ["National Institutes of Health (NIH)", "National Institutes of Health (NIH)", "National Institutes of Health (NIH)", "Georgia Institute of Technology"]
# ["Owner", "Graduate Trainee"]
# ["Ziyang Zhang"]
# ["Emory University"]
# ["Owner", "Research Fellow"]
# ["QIAOCHU XUE"]
# ["Emory University"]
# ["Owner", "Mid-career Tenured Researcher"]
# ["Ka Wing Ho"]
# ["University of Glasgow"]
# ["Owner", "Early Career Tenure-track Researcher"]
# ["Yiqiang Zhang"]
# ["University of Hawaii at Manoa"]
# ["Owner", "Project Personnel", "Early Career Tenure-track Researcher"]
# ["Caleb Harrison", "Mary Ellen Vajravelu"]
# ["University of Pittsburgh", "University of Pittsburgh"]
# ["Owner", "Graduate Trainee"]
# ["Henry Taylor", "National Human Genome Research Institute (NIH - NHGRI)"]
# ["", ""]
#  ["Owner", "Research Fellow"]
#  ["Ginikanwa Onyekaba", "Ginikanwa Onyekaba"]
#  ["Columbia University", "Columbia University"]
# ["Owner", "Graduate Trainee"]
# ["James Crim"]
# ["George Washington University"]
# ["Owner", "Research Assistant", "Graduate Trainee", "Graduate Trainee", "Graduate Trainee"]
# ["Sonali Gupta", "Shivam Sharma", "Onyinye Chukka", "Jay Menuey"]
# ["National Institutes of Health (NIH)", "Georgia Institute of Technology", "Georgia Institute of Technology", "Georgia Institute of Technology"]
# ["Owner", "Graduate Trainee"]
# ["Dawei Guan"]
# ["University of Florida"]
# ["Owner", "Graduate Trainee"]
# ["Gracia Kayembe", "George Washington University"]
# ["George Washington University"]
# ["Owner", "Project Personnel", "Graduate Trainee"]
# ["Jaffer Shah", "Carla Dias"]
# ["Cornell University", "Cornell University"]
# ["Owner", "Research Fellow"]
# ["BA THONG NGUYEN"]
# ["University of Hawaii at Manoa"]
# ["Owner", "Research Fellow"]
# ["BA THONG NGUYEN"]
# ["University of Hawaii at Manoa"]
# ["Owner", "Graduate Trainee"]
# ["José Irizarry"]
# ["Tulane University"]
# ["Owner", "Graduate Trainee"]
# ["Chenyu Huang"]
# ["University of California, Irvine"]
# ["Owner", "Graduate Trainee", "Early Career Tenure-track Researcher", "Graduate Trainee", "Undergraduate Student"]
# ["Miranda Sharp", "Mary Davis", "Lydia Howell", "Kylee Bates"]
# ["Brigham Young University"]
# ["Owner", "Research Fellow"]
# ["Brooke Wolford"]
# ["University of Michigan"]
# ["Owner", "Collaborator", "Collaborator"]
# ["Joshua Amosu", "Sajid Hussain", "Aditya Karki"]
# ["Fisk University", "Fisk University", "Fisk University"]
# ["Owner", "Collaborator"]
# ["Sajid Hussain", "Joshua Amosu"]
# ["Fisk University", "Fisk University"]
# ["Owner", "Undergraduate Student"]
# ["Jigz Cozada"]
# ["Arizona State University"]
# ["Owner", "Research Fellow", "Collaborator"]
# ["Allen Chang", "Ben Gerber"]
# ["University of Massachusetts Medical School", "University of Massachusetts Medical School"]
# ["Owner", "Graduate Trainee"]
# ["Alexander Rader"]
# ["University of Texas Medical Branch (UTMB) at Galveston"]
# ["Owner", "Graduate Trainee"]
# ["Subbaramireddy Remala"]
# ["Mass General Brigham"]
# ["Owner", "Research Associate"]
# ["Stepan Grinek"]
# ["New York Stem Cell Foundation"]
# ["Owner", "Student"]
# ["Isabel Plakas"]
# ["Johns Hopkins University"]
# ["Owner", "Graduate Trainee"]
# ["Sheevang Patel"]
# ["New York Institute of Technology"]
# ["Owner", "Research Fellow", "Graduate Trainee", "Research Fellow", "Graduate Trainee"]
# ["QIAOCHU XUE", "Piaopiao Li", "Jieun Lee", "Dawei Guan"]
# ["Emory University", "Emory University", "Emory University", "University of Florida"]
# ["Owner", "Graduate Trainee", "Other", "Other"]
# ["Micah Hysong", "Jun Qian", "Emily Drzymalla"]
# ["University of North Carolina, Chapel Hill", "All of Us Program Operational Use", "University of North Carolina, Chapel Hill"]
# ["Owner", "Other"]
# ["Seyedeh Neelufar Payrovnaziri"]
# ["University of California, Irvine"]
# ["Owner", "Owner", "Graduate Trainee"]
# ["Meghan Blazey", "Caitlin Dreisbach", "Jaimin Shah"]
# ["University of Rochester", "University of Rochester", "University of Rochester"]
# ["Owner", "Graduate Trainee"]
# ["Dharan Kadiyala"]
# ["Columbia University"]
# ["Owner", "Administrator"]
# ["Jose Gorospe"]
# ["National Institutes of Health (NIH)"]
# ["Owner", "Senior Researcher"]
# ["Andrew Magis"]
# ["Institute for Systems Biology"]
# ["Owner", "Graduate Trainee"]
# ["Nima Shajarian"]
# ["University of California, Irvine"]
# ["Owner", "Graduate Trainee", "Graduate Trainee"]
# ["Veronica Brady", "Ziqi Liu", "Samuel Akyirem"]
# ["University of Texas Health Science Center, Houston", "University of Texas Health Science Center, Houston", "Yale University"]
# ["Owner", "Graduate Trainee"]
# ["Emmanuella Asiedu"]
# ["University of Massachusetts Medical School"]
# ["Owner", "Project Personnel", "Graduate Trainee"]
# ["Jin Zhou", "Aubrey Jensen", "Jonathan Hori"]
# ["University of California, Los Angeles", "University of Arizona", "University of California, Los Angeles"]
# ["Owner", "Project Personnel", "Project Personnel"]
# ["Soumya Kini", "Justin Hill"]
# ["The MITRE Corporation", "The MITRE Corporation"]
# ["Owner", "Graduate Trainee"]
# ["Brooke Morris", "Baylor University"]
# [""]
# ["Owner", "Graduate Trainee", "Project Personnel", "Early Career Tenure-track Researcher"]
# ["Whitney Schutz", "Thomas McCoy", "Crystal Epstein"]
# ["University of North Carolina, Greensboro", "University of North Carolina, Greensboro", "University of North Carolina, Greensboro"]
# ["Owner"]
# ["Joanne Cole"]
# ["University of Colorado, Denver"]
# ["Owner"]
# ["Allen Seylani"]
# ["University of California, Riverside"]
# ["Owner", "Graduate Trainee", "Undergraduate Student"]
# ["Zain Jabbar", "Jeremiah Dy"]
# ["University of Hawaii at Manoa", "University of Hawaii at Manoa"]
# ["Owner", "Collaborator", "Collaborator"]
# ["Breckin Forstrom", "Mary Davis", "Christian Betteridge"]
# ["Brigham Young University", "Brigham Young University", "Brigham Young University"]
# ["Owner", "Research Fellow"]
# ["xuan zhou"]
# ["University of Copenhagen"]
# ["Owner", "Project Personnel", "Early Career Tenure-track Researcher"]
# ["Xiao Zhang", "Chamika Hawkins-Taylor"]
# ["Xavier University of Louisiana"]
# ["Owner", "Early Career Tenure-track Researcher"]
# ["Ghada Soliman", "Aritz Irizar"]
# ["City University of New York (CUNY)", "Icahn School of Medicine at Mount Sinai"]
# ["Owner", "Collaborator", "Collaborator", "Collaborator"]
# ["Amber Vermeesch", "Whitney Schutz", "Thomas McCoy", "Crystal Epstein"]
# ["University of North Carolina, Greensboro", "University of North Carolina, Greensboro", "University of North Carolina, Greensboro", "University of North Carolina, Greensboro"]
# ["Owner", "Graduate Trainee"]
# ["Veronica Brady", "Samuel Akyirem"]
# ["University of Texas Health Science Center, Houston", "Yale University", "University of Texas Health Science Center, Houston"]
# ["Owner", "Graduate Trainee"]
# ["James Russ-Silsby"]
# ["University of Exeter"]
# ["Owner", "Project Personnel", "Late Career Tenured Researcher", "Graduate Trainee"]
# ["Matteo D'Antonio", "Robert Greenes", "Jean Gonzalez"]
# ["University of California, San Diego", "Arizona State University", "University of California, San Diego"]
# ["Owner", "Research Fellow"]
# ["Huan Mo"]
# ["National Human Genome Research Institute (NIH-NHGRI)"]
# ["Owner", "Project Personnel", "Research Fellow", "Graduate Trainee", "Early Career Tenure-track Researcher"]
# ["Jeffrey Haessler", "Harriett Fuller", "Boya Guo", "Burcu Darst"]
# ["Fred Hutchinson Cancer Research Center"]
# ["Owner", "Project Personnel"]
# ["Jaffer Shah"]
# ["Cornell University"]
# ["Owner", "Graduate Trainee"]
# ["Yashu Vashishath", "Yashu Vashishath"]
# ["University of North Texas", "University of North Texas"]
#  ["Owner", "Graduate Trainee"]
#  ["Christopher Doan"]
#  ["University of Texas Medical Branch (UTMB) at Galveston"]
# ["Owner", "Graduate Trainee"]
# ["Ipek Ensari", "Brianna Gibbs"]
# ["Icahn School of Medicine at Mount Sinai", "Icahn School of Medicine at Mount Sinai"]
# ["Owner", "Graduate Trainee"]
# ["xueting wang", "Yale University"]
# []
# ["Owner"]
# ["Nashra Bukhari"]
# ["New York City Health & Hospitals"]
# ["Owner", "Undergraduate Student"]
# ["Jessica Hong", "Brown University"]
# ["Brown University"]
# ["Owner"]
# ["Kassaye Yitbarek Yigzaw"]
# ["University Hospital of North Norway"]
# ["Owner"]
# ["Juanita Morris"]
# ["National Pan-Hellenic Council"]
# ["Owner", "Graduate Trainee", "Graduate Trainee"]
# ["Junius Rosario", "itza garcia"]
# ["Philadelphia College of Osteopathic Medicine", "Philadelphia College of Osteopathic Medicine"]
# ["Owner", "Research Fellow", "Project Personnel"]
# ["frhaan zahrawi", "Khaled Zahrawi"]
# ["Yale University", "Yale University"]
# ["Owner", "Project Personnel"]
# ["Weibin Zhang"]
# ["University of Texas Medical Branch (UTMB) at Galveston"]
# ["Owner", "Graduate Trainee"]
# ["Chenyu Huang"]
# ["University of California, Irvine"]
# ["Owner", "Project Personnel"]
# ["Kelsy Alaine Broadaway"]
# ["University of North Carolina, Chapel Hill"]
# ["Owner", "Graduate Trainee", "Graduate Trainee"]
# ["Maaz Imam", "Coulter Johnston", "Jiajun Luo"]
# ["University of Chicago", "University of Chicago", "University of Chicago"]
# ["Owner", "Project Personnel"]
# ["Ariel Aptekmann"]
# ["Hackensack University Medical Center"]
# ["Owner", "Senior Researcher"]
# ["Liliana Lombardi De Sa"]
# ["Sun River Health"]
# ["Owner", "Project Personnel", "Early Career Tenure-track Researcher", "Graduate Trainee", "Graduate Trainee", "Early Career Tenure-track Researcher", "Graduate Trainee", "Early Career Tenure-track Researcher", "Project Personnel", "Graduate Trainee"]
# ["Rohith Ravindranath", "Billy Caceres", "Yashika Sharma", "Vince Nguyen", "Stephanie Cook", "Joseph Belloir", "Ipek Ensari", "Danny Doan", "Chenziheng Weng"]
# ["Stanford University", "Columbia University", "Columbia University", "Columbia University", "New York University", "Columbia University", "Icahn School of Medicine at Mount Sinai", "Columbia University", "New York University"]
# ["Owner", "Early Career Tenure-track Researcher"]
# ["Abiodun Otolorin"]
# ["Howard University"]
# ["Owner", "Owner", "Collaborator", "Collaborator", "Collaborator"]
# ["Steve Johnson", "Lisiane Pruinelli", "Tim Meyer", "Ragnhildur Bjarnadottir", "Marisa Sileo"]
# ["University of Minnesota", "University of Minnesota", "University of Minnesota", "University of Florida", "Boston Children's Hospital"]
# ["Owner", "Project Personnel", "Graduate Trainee"]
# ["Blake Fortes", "Tim Banh", "Ramin Talebi"]
# ["University of California, Los Angeles", "University of California, Los Angeles", "University of California, Los Angeles"]
# ["Owner", "Research Fellow"]
# ["Addam Reynolds"]
# ["University of Southern California"]
# ["Owner", "Graduate Trainee", "Collaborator", "Collaborator"]
# ["Dhairya Upadhyay", "Souptik Barua", "Adeep Kulkarni"]
# ["New York University", "New York University, Grossman School of Medicine", "New York University, Grossman School of Medicine"]
# ["Owner", "Undergraduate Student"]
# ["Yang Yang"]
# ["Georgia Institute of Technology"]
# ["Owner", "Student"]
# ["Jack Cummins"]
# ["Manchester-Essex Regional High School"]
# ["Owner", "Undergraduate Student"]
# ["Raja Allmdar Tariq Ali"]
# ["Indiana University"]
# ["Owner", "Research Associate"]
# ["Patrick Allaire"]
# ["Marshfield Clinic Research Institute"]
# ["Owner", "Graduate Trainee", "Research Assistant", "Other", "Other", "Mid-career Tenured Researcher", "Other", "Senior Researcher", "Project Personnel"]
# ["Robert Meller", "Shashwat Deepali Nagar", "Sonali Gupta", "Roxana Loperena Cortes", "Francis Ratsimbazafy", "King Jordan", "Kelsey Mayo", "Juan Kehoe", "Elena Moseyko"]
# ["Morehouse School of Medicine", "Georgia Institute of Technology", "National Institutes of Health (NIH)", "All of Us Program Operational Use", "All of Us Program Operational Use", "Georgia Institute of Technology", "All of Us Program Operational Use", "All of Us Program Operational Use", "All of Us Program Operational Use"]
# ["Owner", "Project Personnel"]
# ["Stefanee Tillman"]
# ["All of Us Researcher Academy/RTI International"]
#  ["Owner", "Research Fellow", "Graduate Trainee"]
#  ["Seth Sharp", "Hector Ortega"]
#  ["Stanford University", "Stanford University"]
# ["Owner"]
# ["Nasser Sharareh"]
# ["University of Utah"]
# ["Owner", "Graduate Trainee", "Graduate Trainee"]
# ["Ravi Radhakrishnan", "Sahil Kulkarni", "Jonathan Nukpezah"]
# ["University of Pennsylvania", "University of Pennsylvania", "University of Pennsylvania"]
# ["Owner", "Collaborator"]
# ["Yong Eun", "Bettina Therese Escolano"]
# ["New York City Health & Hospitals", "New York City Health & Hospitals"]
# ["Owner", "Graduate Trainee"]
# ["Jiacheng Miao"]
# ["University of Wisconsin, Madison"]
# ["Owner", "Graduate Trainee"]
# ["Heyang Ji"]
# ["Indiana University"]
# ["Owner", "Graduate Trainee"]
# ["Lorna Jenkins"]
# ["University of South Florida"]
# ["Owner", "Early Career Tenure-track Researcher"]
# ["Francisco Munoz"]
# ["University of Puerto Rico Comprehensive Cancer Centre"]
#  ["Varsha Varkhedi", "Jo-Hsuan Wu", "Sophia Sidhu", "Sally Baxter", "Bharanidharan Radha Saseendrakumar", "Kaela Acuff", "Alison Chan"]
#  ["Undergraduate Student", "Research Fellow", "Graduate Trainee", "Research Fellow", "Project Personnel", "Graduate Trainee", "Graduate Trainee"]
#  ["University of California, San Diego", "University of California, San Diego", "University of California, San Diego", "University of California, San Diego", "University of California, San Diego", "University of California, San Diego", "University of California, San Diego"]
# ["Owner", "Research Fellow"]
# ["Bowen Yan"]
# ["University of Florida"]
# ["Owner", "Research Fellow"]
# ["Prashant Rao"]
# ["Beth Israel Deaconess Medical Center"]
# ["Owner", "Graduate Trainee"]
# ["charbel Bou-Khalil"]
# ["Stanford University"]
# ["Owner", "Research Fellow"]
# ["Samantha Carreon", "Jessica Meers"]
# ["Baylor College of Medicine", "University of Miami"]
# ["Owner", "Mid-career Tenured Researcher", "Graduate Trainee", "Early Career Tenure-track Researcher"]
# ["Gang Han", "Ashley Kurian", "Ya-Ching Huang"]
# ["Texas A&M University", "Texas A&M University", "Texas A&M University"]
# ["Owner", "Project Personnel", "Project Personnel", "Early Career Tenure-track Researcher"]
# ["Shayaa Muhammad", "Scott Jones", "Stephanie Izard", "Amil Tan"]
# ["City University of New York (CUNY)", "Northwell Health", "Northwell Health", "City University of New York (CUNY)"]
# ["Owner", "Graduate Trainee"]
# ["Selam Harar"]
# ["George Mason University"]
# ["Owner", "Undergraduate Student", "Undergraduate Student", "Undergraduate Student"]
# ["Liv VanderBeischel", "Leodivina Dodoo", "Ashley McNatt"]
# ["Arizona State University", "Arizona State University", "Arizona State University"]
# ["Owner"]
# ["Fred LaPolla"]
# ["New York University, Grossman School of Medicine"]
# ["Owner", "Mid-career Tenured Researcher", "Project Personnel"]
# ["Nilanjan Chatterjee", "Wen Shi"]
# ["Johns Hopkins University", "Johns Hopkins University"]
# ["Owner", "Project Personnel", "Early Career Tenure-track Researcher"]
# ["Trey-Rashad Hawkins", "Meiko Thompson"]
# ["All of Us Researcher Academy/RTI International", "Southern University at New Orleans"]
# ["Owner", "Graduate Trainee"]
# ["Yining Huang", "Harvard Medical School"]
# ["Harvard Medical School"]
# ["Owner", "Graduate Trainee", "Graduate Trainee"]
# ["Michelle Ko", "Ramin Talebi"]
# ["University of California, Los Angeles", "University of California, Los Angeles"]
# ["Owner", "Early Career Tenure-track Researcher", "Undergraduate Student"]
# ["Caitlin Dreisbach", "Carol Li"]
# ["University of Rochester", "University of Rochester"]
# ["Owner", "Collaborator", "Collaborator"]
# ["Christian Betteridge", "Mary Davis", "Breckin Forstrom"]
# ["Brigham Young University", "Brigham Young University", "Brigham Young University"]
# ["Owner", "Early Career Tenure-track Researcher"]
# ["Alisa Manning"]
# ["Mass General Brigham"]
# ["Owner", "Graduate Trainee"]
# ["Veronica Brady", "Samuel Akyirem"]
# ["University of Texas Health Science Center, Houston", "Yale University"]
# ["Owner", "Graduate Trainee"]
# ["Yasser Alharbi"]
# ["Nova Southeastern University"]
# ["Owner", "Research Fellow"]
# ["Alicia Huerta"]
# ["Broad Institute"]
#  ["Owner", "Mid-career Tenured Researcher", "Project Personnel", "Other"]
#  ["Junguk Hur", "Parker Combs", "Christianah Jemiyo"]
#  ["University of North Dakota", "University of North Dakota", "University of North Dakota"]
# ["Owner", "Graduate Trainee"]
# ["Citina Liang"]
# ["University of Southern California"]
# ["Owner", "Mid-career Tenured Researcher"]
# ["Azad Bhuiyan"]
# ["Jackson State University"]
# ["Owner", "Undergraduate Student"]
# ["Grace Borchert"]
# ["Washington State University"]
# ["Owner"]
# ["Hongyan Xu"]
# ["Augusta University"]
# ["Owner"]
# ["Tam Tran"]
# ["National Human Genome Research Institute (NIH - NHGRI)"]
# ["Owner", "Graduate Trainee"]
# ["Jason Gillman"]
# ["University of Texas Health Science Center, Houston"]
# ["Owner", "Project Personnel", "Research Associate"]
# ["Kristin Glaze", "Javan Carter"]
# ["All of Us Researcher Academy/RTI International", "All of Us Researcher Academy/RTI International"]
# Names = ["Qixuan Jin", "Haoran Zhang", "Xuhai Xu", "Kai Wang", "Vinith Suriyakumar", "Ravi Mandla"]
# Roles = ["Owner", "Graduate Trainee", "Graduate Trainee", "Research Fellow", "Research Fellow", "Graduate Trainee", "Project Personnel"]
# Institutions = ["Massachusetts Institute of Technology", "Massachusetts Institute of Technology", "Massachusetts Institute of Technology", "Massachusetts Institute of Technology", "Massachusetts Institute of Technology", "Massachusetts Institute of Technology", "Broad Institute"]
# An error occurred while parsing: invalid syntax (<unknown>, line 1)
# ["Owner", "Undergraduate Student", "Undergraduate Student"]
# ["Viera Garcia", "Ayesha Smith"]
# ["Arizona State University", "Arizona State University"]
# ["Owner", "Collaborator", "Collaborator"]
# ["Yang Yu", "Caitlin Dreisbach"]
# ["University of Rochester", "University of Rochester"]
# ["Owner"]
# ["James White"]
# ["University of Florida"]
# ["Owner", "Project Personnel"]
# ["Vincent Chen", "Nicholas Tedesco"]
# ["University of Michigan", "University of Michigan"]
# ["Owner", "Graduate Trainee", "Graduate Trainee"]
# ["Samuel Salib", "Joshua Kim"]
# ["University of California, Irvine", "Duke University"]
# ["Owner"]
# ["Wendy White"]
# ["Tougaloo College"]
# ["Owner"]
# ["Frances Dancer"]
# ["Jackson State University"]
# ["Owner", "Early Career Tenure-track Researcher"]
# ["Faith Brown"]
# ["Jackson State University"]
# ["Owner", "Research Associate"]
# ["Jose Flores"]
# ["Memorial Sloan Kettering Cancer Center"]
# ["Owner", "Graduate Trainee"]
# ["Ehsan Alipour"]
# ["University of Washington"]
# ["Owner", "Collaborator", "Collaborator", "Collaborator"]
# ["Sonali Gupta", "Vincent Lam", "Varsha Srinivasan", "Jasmyn Pellebon"]
# ["National Institutes of Health (NIH)", "National Institutes of Health (NIH)", "Georgia Institute of Technology", "Georgia Institute of Technology"]
# ["Owner", "Project Personnel", "Mid-career Tenured Researcher"]
# ["TIMOTHY COFFIN", "Farrokh Alemi"]
# ["George Mason University", "George Mason University"]
#
# ["Andrew Brown", "Reshma Gurung", "Niya Holifield", "Muhammad G. Khodary Omar", "Deepa Bedi", "Chitra Nayak", "Chastity Bradford"]
#
# ["Owner", "Graduate Trainee", "Undergraduate Student", "Mid-career Tenured Researcher"]
#
# ["Tuskegee University"]
# ["Owner", "Project Personnel"]
# ["Shayaa Muhammad"]
# ["City University of New York (CUNY)"]
# ["Owner", "Research Fellow"]
# ["Chenjie Zeng"]
# ["National Human Genome Research Institute (NIH - NHGRI)"]
# ["Owner", "Graduate Trainee", "Research Fellow", "Late Career Tenured Researcher"]
# ["Tyler Ryan", "Eric Nielsen", "Ben Gerber"]
# ["University of Massachusetts Medical School", "University of Massachusetts Medical School", "University of Massachusetts Medical School"]
# ["Owner", "Research Fellow"]
# ["QIAOCHU XUE"]
# ["Emory University"]
# ["Owner", "Collaborator"]
# ["Emily Drzymalla", "Reagan Ballard"]
# ["University of North Carolina, Chapel Hill", "University of North Carolina, Chapel Hill"]
# ["Owner", "Collaborator"]
# ["Lisette Martinez", "Katrina Yamazaki"]
# ["California State University Los Angeles", "The Community Health Center"]
# ["Owner", "Graduate Trainee", "Early Career Tenure-track Researcher"]
# ["Samuel Akyirem", "Veronica Brady"]
# ["Yale University", "University of Texas Health Science Center, Houston"]
# ["Owner", "Graduate Trainee", "Research Fellow"]
# ["Nanda Nayak", "Megan Lancaster"]
# ["Vanderbilt University Medical Center", "Vanderbilt University Medical Center"]
# ["Owner", "Graduate Trainee"]
# ["Nikita Piryani"]
# ["Medical College of Wisconsin"]
# ["Owner", "Undergraduate Student"]
# ["Taiwo Fakunle"]
# ["Arizona State University"]
# ["Owner", "Undergraduate Student", "Undergraduate Student", "Other", "Undergraduate Student"]
# ["Zaire Hills", "Hollie Brown", "Charcacia Sanders", "Amaya Ashley"]
# ["Prairie View A&M University"]
# ["Owner", "Research Fellow"]
# ["Joshua Geiger"]
# ["University of Rochester"]
# 1.["Owner", "Graduate Trainee", "Research Fellow", "Early Career Tenure-track Researcher"]
# 2.["Quan Nguyen", "Sevda Molani", "Andrew Baumgartner"]
# 3.["Institute for Systems Biology", "Institute for Systems Biology", "Institute for Systems Biology"]
# An error occurred while parsing: malformed node or string on line 1: <ast.Subscript object at 0x7adc22398df0>
# ["Owner", "Graduate Trainee"]
# ["Samuel Akyirem"]
# ["Yale University"]
# ["Owner", "Collaborator"]
# ["Cecilia Lopez", "Jakhari Ross"]
# ["Arizona State University", "Arizona State University"]
# ["Owner", "Mid-career Tenured Researcher"]
# ["German Rosas-Acosta"]
# ["University of Texas at El Paso"]
# ["Owner", "Undergraduate Student"]
# ["Jakhari Ross"]
# ["Arizona State University"]
# ["Owner", "Mid-career Tenured Researcher"]
# ["Gerardo Lazaro"]
# ["Centers for Disease Control and Prevention (CDC)"]
# ["Owner", "Graduate Trainee"]
# ["Valerie Sant"]
# ["University of Texas at Austin"]
# ["Owner", "Undergraduate Student"]
# ["Elijah Taylor"]
# ["University of Maryland, Baltimore"]
# ["Owner", "Project Personnel", "Collaborator"]
# ["Danielle Johnson", "Bradley Webb"]
# ["All of Us Researcher Academy/RTI International", "Virginia Commonwealth University"]
# ["Owner", "Collaborator"]
# ["Alexa Wnorowski", "Matthew Blank"]
# ["The Jackson Laboratory", "Baylor College of Medicine"]
# ["Owner"]
# ["Tomas Nuño"]
# ["University of Arizona"]
# ["Owner", "Graduate Trainee"]
# ["Kayvan Mivehnejad"]
# ["George Washington University"]
# ["Owner", "Project Personnel"]
# ["Alina Gataullina"]
# ["University of California, Davis"]
# ["Owner", "Undergraduate Student"]
# ["Segovia Lucas"]
# ["University of Alabama at Birmingham"]
# ["Owner", "Research Fellow"]
# ["Obed Garcia"]
# ["Stanford University"]
# ["Owner", "Research Fellow", "Project Personnel", "Late Career Tenured Researcher"]
# ["Ernesto Licon", "Steven Hiek", "Argyrios Ziogas"]
# ["University of California, Irvine", "University of California, Irvine", "University of California, Irvine"]
# ["Owner", "Graduate Trainee"]
# ["Shahjalal Chowdhury"]
# ["Tuskegee University"]
# ["Owner", "Undergraduate Student", "Undergraduate Student"]
# ["Pratyusha Panchangam", "gabriela patino"]
# ["Arizona State University", "Arizona State University"]
# ["Owner", "Project Personnel", "Research Fellow"]
# ["Steven Hiek", "Ernesto Licon", "Argyrios Ziogas"]
# ["University of California, Irvine", "University of California, Irvine", "University of California, Irvine"]
# ["Owner", "Research Assistant"]
# ["Toaiva Penelope Hall"]
# ["American Samoa Community Cancer Coalition"]
# ["Owner", "Graduate Trainee"]
# ["Valerie Ray", "North Carolina A&T State University"]
# ["North Carolina A&T State University"]
# ["Owner", "Undergraduate Student"]
# ["Tyler Cerneka"]
# ["Arizona State University"]
# ["Owner"]
# ["Donglan Zhang"]
# ["University of Georgia"]
#
# ["Owner", "Early Career Tenure-track Researcher", "Graduate Trainee"]
#
#
# ["Josephine Li", "Alexandra Barry"]
#
#
# ["Mass General Brigham", "Mass General Brigham"]
# ["Owner", "Graduate Trainee"]
# ["Xiaomi Du"]
# ["University of California, San Diego"]
# ["Owner", "Early Career Tenure-track Researcher"]
# ["Andrew Baumgartner"]
# ["Institute for Systems Biology"]
#
# ["Peter Buto", "Christopher Lord", "Alvaro Alonso", "Vignesh Subbian", "Francis Ratsimbazafy", "Aymone Kouame", "Aniqa Alam", "Konstantinos Sidiropoulos"]
#
#
# ["Owner", "Graduate Trainee", "Project Personnel", "Late Career Tenured Researcher", "Early Career Tenure-track Researcher", "Other", "Other", "Other"]
#
#
# ["Emory University", "All of Us Program Operational Use", "Emory University", "University of Arizona", "All of Us Program Operational Use", "All of Us Program Operational Use", "Nova Southeastern University"]
# ["Owner", "Graduate Trainee"]
# ["Neha Arora"]
# ["Tulane University"]
# ["Owner", "Undergraduate Student"]
# ["Jeremie Abides"]
# ["Arizona State University"]
# ["Owner", "Graduate Trainee"]
# ["Pankaj Vyas", "shenghao xia"]
# ["University of Arizona", "University of Arizona"]
# ["Owner", "Undergraduate Student", "Graduate Trainee"]
# ["DANIEL KUDDABUJJA", "NHAT ANH TRAN"]
# ["Texas Southern University, College of Pharmacy and Health Sciences"]
# ["Owner", "Early Career Tenure-track Researcher"]
# ["Benjamin King"]
# ["University of Maine"]
# ["Owner", "Graduate Trainee"]
# ["Joshua Le"]
# ["University of Vermont"]
# ["Owner", "Senior Researcher"]
# ["Anurag Garikipati", "Robert Adelson"]
# ["Forta Health", "Forta Health"]
# ["Owner", "Research Fellow"]
# ["Hoda Salsabili"]
# ["Purdue University"]
# ["Owner"]
# ["Danielle Rasooly"]
# ["Centers for Disease Control and Prevention (CDC)"]
# ["Owner"]
# ["Megan Coffee"]
# ["New York University, Grossman School of Medicine"]
# ["Owner", "Research Fellow"]
# ["Olubu Adiji"]
# ["Baylor College of Medicine"]
# ["Owner", "Undergraduate Student"]
# ["Timesha Steele"]
# ["Prairie View A&M University"]
# ["Owner", "Early Career Tenure-track Researcher", "Early Career Tenure-track Researcher"]
# ["Vibhuti Gupta", "Hongmei Wang"]
# ["Meharry Medical College", "Texas Southern University, College of Pharmacy and Health Sciences"]
# ["Owner", "Undergraduate Student", "Undergraduate Student", "Other"]
# ["Tia Bullard", "Amira Stephens", "Charcacia Sanders"]
# ["Prairie View A&M University", "Prairie View A&M University", "Prairie View A&M University"]
# ["Owner", "Undergraduate Student", "Early Career Tenure-track Researcher"]
#
# ["Daniel Mattyasovsky", "Eric Butler"]
#
# ["Shaw University", "Shaw University"]
# ["Owner", "Graduate Trainee", "Other", "Undergraduate Student"]
# ["Manxi Yang", "Danielle Forman", "Jacqueline Kim", "Hester Nguyen"]
# ["University of California, Irvine", "University of California, Irvine", "University of California, Irvine", "University of California, Irvine"]
# ["Owner", "Project Personnel"]
# ["Elizabeth Procter-Gray"]
# ["University of Massachusetts, Lowell"]
#  ["Kendelle Lewis", "Autum Herron", "Charcacia Sanders"]
#  ["Owner", "Undergraduate Student", "Undergraduate Student", "Other"]
#  ["Prairie View A&M University", "Prairie View A&M University", "Prairie View A&M University"]
# ["Owner", "Undergraduate Student", "Undergraduate Student"]
# ["Taylor Smith", "Jahari Ennols"]
# ["Prairie View A&M University", "Prairie View A&M University", "Prairie View A&M University"]
# ["Owner", "Undergraduate Student", "Undergraduate Student"]
# ["Peter Mordi", "Ebunoluwa Adelola", "Akeem Laurence"]
# ["Towson University", "Towson University", "Towson University"]
# ["Owner", "Research Associate", "Senior Researcher"]
# ["Louis Lello", "Erik Widen"]
# ["Genomic Prediction", "Genomic Prediction", "Michigan State University"]
# ["Owner", "Senior Researcher"]
# ["Grier Page"]
# ["All of Us Researcher Academy/RTI International"]
# ["Owner", "Graduate Trainee"]
# ["Nolan Kamitaki"]
# ["Broad Institute"]
#  ["Hsing-Chun Wang", "Yike Li", "Jose Pagan", "Donglan Zhang"]
#  ["Owner", "Graduate Trainee", "Early Career Tenure-track Researcher", "Late Career Tenured Researcher", "Mid-career Tenured Researcher"]
#  ["New York University", "Vanderbilt University Medical Center", "New York University", "University of Georgia"]
#  ["Holly Dixon", "Rajvir Badwal", "Kathryn McDougal"]
#  ["Owner", "Undergraduate Student", "Other"]
#  ["Towson University", "Towson University", "Towson University"]
# ["Owner"]
# ["Gary Desir"]
# ["Yale University"]
#
# ["Owner", "Undergraduate Student", "Other", "Early Career Tenure-track Researcher"]
#
#
# ["Victor Alcala", "KIMBERLY RAIFORD", "Eric Butler"]
#
#
# ["Shaw University", "Shaw University", "Shaw University"]
# ["Owner", "Early Career Tenure-track Researcher"]
# ["Ronke Akinkugbe"]
# ["Icahn School of Medicine at Mount Sinai"]
# ["Owner", "Collaborator", "Collaborator"]
# ["Alex Gilchrist", "Sydney Pickett"]
# ["Arizona State University", "Arizona State University"]
# ["Owner", "Graduate Trainee"]
# ["Kateryna Stone"]
# ["University of Cincinnati"]
# Roles = ["Owner", "Graduate Trainee", "Graduate Trainee", "Graduate Trainee", "Graduate Trainee", "Graduate Trainee", "Graduate Trainee", "Graduate Trainee"]
# Names = ["Oge Marques", "Nha Tran", "Nicholas Marques", "Mindy Knowles", "Jennifer Gogova", "Daniel Cuentas", "Chelsea Zuvieta", "Christian Garbin"]
# Institutions = ["Florida Atlantic University", "Florida Atlantic University", "Florida Atlantic University", "Florida Atlantic University", "Florida Atlantic University", "Florida Atlantic University", "Florida Atlantic University", "Florida Atlantic University"]
# An error occurred while parsing: invalid syntax (<unknown>, line 1)
# ["Owner", "Graduate Trainee", "Graduate Trainee"]
# ["Sean Grimm", "Arshia Firdaus"]
# ["George Mason University", "George Mason University"]
# ["Owner", "Mid-career Tenured Researcher"]
# ["Keith Chan"]
# ["City University of New York (CUNY)"]
# ["Owner", "Research Fellow"]
# ["Zachary Strasser"]
# ["Mass General Brigham"]
# ["Owner", "Graduate Trainee", "Graduate Trainee"]
# ["Yashu Vashishath", "Sarah Beaver"]
# ["University of North Texas", "University of North Texas"]
#  ["Owner", "Graduate Trainee", "Research Fellow"]
#  ["Aaron Eisman", "Jacob Barber"]
#  ["Brown University", "Beth Israel Deaconess Medical Center"]
# ["Owner", "Graduate Trainee"]
# ["Paramita Basak Upama"]
# ["Marquette University"]
# ["Owner", "Collaborator"]
# ["Alisa Manning", "Casey Marchek"]
# ["Mass General Brigham", "Mass General Brigham"]
# ["Owner", "Graduate Trainee"]
# ["Toni Pollin", "Jessica Tiner"]
# ["University of Maryland, Baltimore", "University of Maryland, Baltimore"]
# ["Owner"]
# ["Phil Lee"]
# ["Mass General Brigham"]
# ["Owner", "Research Fellow", "Research Assistant", "Graduate Trainee", "Graduate Trainee", "Senior Researcher"]
# ["Vincent Lam", "Sonali Gupta", "Shivam Sharma", "Robin Kee", "Leonardo Marino-Ramirez"]
# ["National Institutes of Health (NIH)", "National Institutes of Health (NIH)", "Georgia Institute of Technology", "National Institutes of Health (NIH)", "National Institutes of Health (NIH)"]
# ["Owner", "Research Fellow"]
# ["Yaolin Pei"]
# ["New York University"]
# ["Owner", "Collaborator"]
# ["Nyasha Chambwe", "Veronica Brady"]
# ["Feinstein Institute for Medical Research", "University of Texas Health Science Center, Houston"]
# ["Owner", "Early Career Tenure-track Researcher"]
# ["Prateek Shukla"]
# ["University of Massachusetts Medical School"]
# ["Owner"]
# ["Haowei Wang"]
# ["Syracuse University"]
# ["Owner", "Undergraduate Student", "Early Career Tenure-track Researcher", "Early Career Tenure-track Researcher", "Graduate Trainee", "Late Career Tenured Researcher"]
# ["Benjamin Weitz", "Daniel Amante", "JungAe Lee", "Emmanuella Demosthenes", "Dedeepya Billa", "Ben Gerber"]
# ["University of Massachusetts Medical School", "University of Massachusetts Medical School", "University of Massachusetts Medical School", "University of Massachusetts Medical School", "University of Massachusetts, Lowell", "University of Massachusetts Medical School"]
# ["Owner", "Undergraduate Student", "Undergraduate Student"]
# ["Lordes Ulloa", "Kaydence Walker"]
# ["Arizona State University", "Arizona State University"]
# ["Owner"]
# ["Elior Rahmani"]
# ["University of California, Los Angeles"]
# ["Owner", "Early Career Tenure-track Researcher", "Graduate Trainee", "Mid-career Tenured Researcher", "Research Fellow"]
# ["Normarie Torres Blasco", "Mario Bermonti-Pérez", "Lianel Rosario", "Julie Dutil", "Caleb Esteban", "Eliut Rivera-Segarra", "Cristina Pena", "Alixida Ramos-Pibernus"]
# ["Ponce Medical School Foundation"]
# ```python
# names = ["Robin Rodriguez", "Kate Steigauf", "Emily Nystrom", "camille routledge", "Angelique Lacava"]
# roles = ["Owner", "Undergraduate Student", "Undergraduate Student", "Undergraduate Student", "Undergraduate Student"]
# institutions = ["Arizona State University", "Arizona State University", "Arizona State University", "Arizona State University", "Arizona State University"]
# ```
# An error occurred while parsing: invalid syntax (<unknown>, line 1)
# ["Owner", "Early Career Tenure-track Researcher"]
# ["Alana Biggers"]
# ["University of Illinois at Chicago"]
# ["Owner"]
# ["Alain Koyama"]
# ["Centers for Disease Control and Prevention (CDC)"]
# ["Owner", "Undergraduate Student"]
# ["Kate Steigauf"]
# ["Arizona State University"]
# ["Owner", "Undergraduate Student"]
# ["Mattieu Pollack"]
# ["University of Maryland, College Park"]
# ["Owner", "Project Personnel", "Graduate Trainee", "Other", "Late Career Tenured Researcher"]
# ["Weibin Zhang", "Daniel Bao", "Alex Bokov", "Suresh Bhavnani"]
# ["University of Texas Medical Branch (UTMB) at Galveston", "University of Texas Health Science Center, San Antonio"]
# ["Owner"]
# ["Ariadne Letra"]
# ["University of Pittsburgh"]
#  ["Mireya Diaz"]
#  ["Owner"]
#  ["Western Michigan University, Homer Stryker M.D. School of Medicine"]
# ["Owner"]
# ["Vinicius Borges"]
# ["Marshall University"]
# ["Owner", "Collaborator", "Collaborator"]
# ["Robin Rodriguez", "Kate Steigauf", "Angelique Lacava"]
# ["Arizona State University", "Arizona State University", "Arizona State University"]
# ["Owner", "Graduate Trainee", "Collaborator"]
# ["Mitra Mosslemi", "Chip Shaw"]
# ["University of Pittsburgh", "Texas Tech University Health Sciences Center"]
# ["Owner"]
# ["Raha Dastgheyb"]
# ["Johns Hopkins University"]
# ["Owner", "Undergraduate Student"]
# ["Joshua Krause"]
# ["University of Wisconsin, La Crosse"]
#  ["Yossi Farjoun", "marcus klarqvist"]
#  ["Owner", "Project Personnel"]
#  ["Broad Institute", "Broad Institute"]
# ```python
# names = ["Amy Wagler", "William Agyapong"]
# roles = ["Owner", "Project Personnel"]
# institutions = ["University of Texas at El Paso", "University of Texas at El Paso"]
# ```
# An error occurred while parsing: invalid syntax (<unknown>, line 1)
# ["Owner"]
# ["Hongyan Xu"]
# ["Augusta University"]
# ["Owner", "Graduate Trainee", "Mid-career Tenured Researcher"]
# ["Yike Li", "Hsing-Chun Wang", "Donglan Zhang"]
# ["Vanderbilt University Medical Center", "New York University", "University of Georgia"]
# ["Owner", "Research Fellow"]
# ["Sini Nagpal"]
# ["Georgia Institute of Technology"]
#  ["Emmanuella Demosthenes", "Dedeepya Billa", "Ben Gerber", "Benjamin Weitz", "Daniel Amante"]
#  ["Owner", "Graduate Trainee", "Late Career Tenured Researcher", "Undergraduate Student", "Early Career Tenure-track Researcher"]
#  ["University of Massachusetts Medical School", "University of Massachusetts, Lowell", "University of Massachusetts Medical School", "University of Massachusetts Medical School", "University of Massachusetts Medical School"]
# ["Owner", "Project Personnel"]
# ["James Laughery"]
# ["ChristianaCare"]
# ["Owner", "Graduate Trainee", "Mid-career Tenured Researcher", "Mid-career Tenured Researcher"]
# ["Andre Nguyen", "Hongyan Xu", "Christopher Williams"]
# ["Xavier University of Louisiana", "Augusta University", "Xavier University of Louisiana"]
# ["Owner", "Project Personnel"]
# ["Rohit Vashisht"]
# ["University of California, San Francisco"]
# ["Owner"]
# ["Roland Sturm"]
# ["Pardee RAND Graduate School"]
# ["Owner", "Collaborator", "Collaborator"]
# ["Ridgely Fisk Green", "Ramal Moonesinghe"]
# ["Centers for Disease Control and Prevention (CDC)", "Centers for Disease Control and Prevention (CDC)"]
# ["Owner", "Research Fellow"]
# ["Joana Andoh"]
# ["Johns Hopkins University"]
#  ["Ramal Moonesinghe"]
#  ["Late Career Tenured Researcher"]
#  ["Centers for Disease Control and Prevention (CDC)"]
# ["Owner", "Research Fellow", "Graduate Trainee"]
# ["Michael Yi", "Sylvia Pena"]
# ["Northwestern University", "Marquette University"]
# ["Owner", "Graduate Trainee"]
# ["Frances Golden"]
# ["University of California, Irvine"]
# ["Owner", "Graduate Trainee", "Project Personnel"]
# ["Jacob Abshire", "Hui Wang"]
# ["University of Alabama at Birmingham", "University of Alabama"]
#
#    ["Owner", "Graduate Trainee", "Other", "Graduate Trainee", "Graduate Trainee", "Graduate Trainee", "Graduate Trainee"]
#
#
#    ["Yufan Gong", "Nathan Wong", "Trinh Do", "Meleeka Akbarpour", "Frances Golden", "Divya Devineni"]
#
#
#    ["University of California, Los Angeles", "University of California, Irvine", "University of California, Irvine", "University of California, Irvine", "University of California, Irvine", "University of California, Irvine"]
# ["Owner", "Graduate Trainee"]
# ["Md Raihan Mia", "Marquette University"]
# ["Marquette University"]
# ["Owner", "Graduate Trainee"]
# ["Bowen Wang"]
# ["Rensselaer Polytechnic Institute"]
# ["Owner", "Graduate Trainee", "Late Career Tenured Researcher"]
# ["Tyler Ryan", "Ben Gerber"]
# ["University of Massachusetts Medical School", "University of Massachusetts Medical School"]
# ["Owner", "Undergraduate Student"]
# ["Christian Betteridge"]
# ["Brigham Young University"]
# ["Owner", "Collaborator"]
# ["Marcus Pezzolesi", "Devorah Stucki"]
# ["University of Utah", "University of Utah"]
# ["Owner"]
# ["Aize Cao"]
# ["Meharry Medical College"]
# ["Owner", "Graduate Trainee"]
# ["Joan LLabre"]
# ["Rensselaer Polytechnic Institute"]
# ["Owner", "Undergraduate Student"]
# ["Stevan Lazic"]
# ["University of Wisconsin, La Crosse"]
# ["Owner"]
# ["Judith Aponte"]
# ["City University of New York (CUNY)"]
# ["Owner", "Project Personnel"]
# ["Jon Sundin", "Carina Grunberg"]
# ["AI LA Community, Inc", "AI LA Community, Inc"]
# ["Owner", "Research Fellow"]
# ["Vincent Lam"]
# ["National Institutes of Health (NIH)"]
# ["Owner", "Research Fellow"]
# ["Md Tuhin Sheikh"]
# ["Yale University"]
# ["Owner", "Project Personnel"]
# ["Carina Grunberg"]
# ["AI LA Community, Inc"]
# ["Owner", "Graduate Trainee"]
# ["Hunter Deaton"]
# ["Lincoln Memorial University-DeBusk College of Osteopathic Medicine"]
#  ["Owner", "Late Career Tenured Researcher"]
#  ["Cheryl McCullumsmith"]
#  ["University of Toledo"]
# ["Owner", "Undergraduate Student"]
# ["Margaret Lenhart"]
# ["University of Notre Dame"]
# ["Owner", "Research Assistant"]
# ["Stephen Tsou"]
# ["AI LA Community, Inc"]
# ["Owner"]
# ["Carl Yang"]
# ["Emory University"]
# ["Owner", "Senior Researcher"]
# ["Farida Akhtari"]
# ["National Institute of Environmental Health Sciences (NIH - NIEHS)"]
# ["Owner", "Mid-career Tenured Researcher"]
# ["Bohdan Khomtchouk"]
# ["Indiana University"]
# ["Owner", "Graduate Trainee"]
# ["Jacob Rich", "Jacob Rich"]
# ["Case Western Reserve University"]
# ["Owner"]
# ["Kalpana Raja"]
# ["University of Texas Health Science Center, Houston"]
# ["Owner", "Research Fellow", "Project Personnel"]
# ["Jasmine Baker", "Julie Coleman"]
# ["Baylor College of Medicine"]
# ["Owner", "Undergraduate Student"]
# ["Alex Gilchrist"]
# ["Arizona State University"]
# ["Owner", "Project Personnel", "Project Personnel", "Research Fellow"]
# ["Ravi Mandla", "Philip Schroeder", "Alicia Huerta"]
# ["Broad Institute", "Broad Institute", "Broad Institute", "Mass General Brigham"]
# ["Owner", "Graduate Trainee"]
# ["Anthony Akande"]
# ["University of Texas Health Science Center, Houston"]
# ["Owner", "Research Fellow"]
# ["Nicholas Johnson"]
# ["Centers for Disease Control and Prevention (CDC)"]
# ["Owner", "Project Personnel"]
# ["Sarah Colbert"]
# ["Icahn School of Medicine at Mount Sinai"]
# ["Owner"]
# ["Eric Triplett"]
# ["University of Florida"]
# ["Owner", "Project Personnel", "Early Career Tenure-track Researcher"]
# ["Phoebe Finneran", "Michael Honigberg"]
# ["Broad Institute", "Broad Institute"]
# ["Owner", "Graduate Trainee"]
# ["Yujie Wei"]
# ["Johns Hopkins University"]
# ["Owner", "Research Fellow"]
# ["Nicholas Johnson"]
# ["Centers for Disease Control and Prevention (CDC)"]
# ["Owner", "Graduate Trainee"]
# ["Lauren Murphy"]
# ["University of Arizona"]
# ["Owner", "Graduate Trainee"]
# ["Nicholas Bartelo"]
# ["Cornell University"]
# ["Owner"]
# ["Phil Lee"]
# ["Mass General Brigham"]
# ["Owner"]
# ["Jammie Hopkins"]
# ["Morehouse School of Medicine"]
# ["Owner", "Graduate Trainee", "Graduate Trainee", "Graduate Trainee"]
# ["xiaodi hu", "Alexander Warner", "Kenneth Fan"]
# ["Massachusetts Institute of Technology", "Massachusetts Institute of Technology", "Massachusetts Institute of Technology"]
# ["Owner", "Graduate Trainee", "Mid-career Tenured Researcher"]
# ["Wenbo Fei", "Yuanjia Wang"]
# ["Columbia University", "Columbia University"]
# ["Owner", "Administrator"]
# ["James Gao"]
# ["National Institutes of Health (NIH)"]
#  ["Seema Aggarwal"]
#  ["Early Career Tenure-track Researcher"]
#  ["University of Texas Health Science Center, Houston"]
# ["Owner", "Graduate Trainee"]
# ["Emily Strouphauer", "Baylor College of Medicine"]
# ["Baylor College of Medicine"]
# ["Owner", "Senior Researcher", "Project Personnel", "Senior Researcher"]
# ["lin mirshahi", "Jonathan Luo", "Alexander Chang"]
# ["Geisinger Clinic", "Geisinger Clinic", "Geisinger Clinic"]
# ["Owner", "Mid-career Tenured Researcher"]
# ["Paul Macey"]
# ["University of California, Los Angeles"]
# ["Owner", "Project Personnel", "Research Fellow"]
# ["Bjorn Kluwe", "Amaris Williams"]
# ["Ohio State University", "Ohio State University"]
# ["Owner", "Collaborator", "Collaborator"]
# ["Bijun Kannadath", "Nia Nikkhahmanesh", "Jiali Ling"]
# ["University of Arizona", "University of Arizona", "University of Arizona"]
# ["Owner", "Mid-career Tenured Researcher"]
# ["Mary Helen Mays"]
# ["University of Puerto Rico Medical Sciences"]
# ["Owner", "Graduate Trainee", "Undergraduate Student", "Graduate Trainee", "Mid-career Tenured Researcher"]
# ["Leslie Flaco", "Eric Diaz", "Denisse Urenda", "Amy Wagler"]
# ["University of Texas at El Paso", "University of Texas at El Paso", "University of Texas at El Paso", "University of Texas at El Paso"]
# ["Owner", "Project Personnel"]
# ["Tim Majarian"]
# ["Mass General Brigham"]
# ["Owner", "Research Fellow"]
# ["Beatrix Krause"]
# ["University of California, Los Angeles"]
#
# ["Sally Baxter", "Priyanka Soe", "Michael Wolfe", "Cecilia Vallejos", "Bharanidharan Radha Saseendrakumar"]
#
#
# ["Research Fellow", "Project Personnel", "Graduate Trainee", "Undergraduate Student", "Project Personnel"]
#
#
# ["University of California, San Diego", "University of California, San Diego", "University of California, San Diego", "University of California, San Diego", "University of California, San Diego"]
# ["Owner", "Project Personnel"]
# ["LaTerrica Williams"]
# ["Baylor College of Medicine"]
# ["Owner", "Research Fellow"]
# ["Ahmed Alkanaq"]
# ["Broad Institute"]
# ["Owner", "Collaborator"]
# ["Anand Gandhi", "Bijun Kannadath"]
# ["Banner Health", "University of Arizona"]
# ["Owner", "Research Fellow"]
# ["Md Huda"]
# ["University of California, Davis"]
# ["Owner"]
# ["Francesca Vitali"]
# ["University of Arizona"]
# ["Owner", "Undergraduate Student"]
# ["Jui Yu Kao"]
# ["University of California, San Francisco"]
# ["Owner", "Early Career Tenure-track Researcher"]
# ["Miriam Udler"]
# ["Broad Institute"]
# ["Owner", "Graduate Trainee"]
# ["Beatrice Morrow"]
# ["Baylor College of Medicine"]
# ["Owner", "Early Career Tenure-track Researcher"]
# ["Chamika Hawkins-Taylor"]
# ["Xavier University of Louisiana"]
# ["Owner", "Late Career Tenured Researcher"]
# ["Snigdhansu Chatterjee"]
# ["University of Minnesota"]
# ["Owner", "Graduate Trainee"]
# ["Kiandra Smith"]
# ["Morehouse School of Medicine"]
# ["Owner", "Undergraduate Student"]
# ["Rohit Nandakumar"]
# ["Arizona State University"]
# ["Owner", "Project Personnel", "Early Career Tenure-track Researcher", "Graduate Trainee"]
# ["Matthew Robinson", "Humberto López Castillo", "Assad Khan"]
# ["University of Central Florida", "University of Central Florida", "University of Central Florida"]
# ["Owner", "Graduate Trainee"]
# ["Jiada Zhan"]
# ["Emory University"]
# ["Owner", "Graduate Trainee", "Collaborator"]
# ["Xochitl Pablos-Velez", "Bassent Abdelbary"]
# ["University of Texas, Rio Grande Valley", "University of Texas, Rio Grande Valley"]
# ["Owner", "Collaborator"]
# ["Mia Newlin-Bradner", "Glenna Schluck"]
# ["Florida State University", "Florida State University"]
# ["Owner", "Research Fellow"]
# ["Alexandra Ralevski"]
# ["Institute for Systems Biology"]
# ["Owner", "Early Career Tenure-track Researcher", "Late Career Tenured Researcher"]
# ["Feifan Liu", "Ben Gerber"]
# ["University of Massachusetts Medical School", "University of Massachusetts Medical School", "University of Massachusetts Medical School", "All of Us Program Operational Use"]
# ["Owner", "Undergraduate Student"]
# ["Rohit Nandakumar"]
# ["Arizona State University"]
# ["Owner"]
# ["Whitney Teagle"]
# ["National Institutes of Health (NIH)"]
# ["Owner", "Other", "Late Career Tenured Researcher", "Other"]
# ["Timothy Lezon", "Judith Klein", "John Maier"]
# ["University of Pittsburgh", "Arizona State University", "University of Pittsburgh"]
# ["Owner", "Collaborator"]
# ["Sarah Jackson", "Jalen Brown"]
# ["National Institutes of Health (NIH)", "National Cancer Institute (NIH - NCI)"]
# ["Owner", "Research Fellow"]
# ["Erik Almazan"]
# ["Mass General Brigham"]
# ["Owner"]
# ["Aryana Sepassi"]
# ["University of California, Irvine"]
# ["Owner"]
# ["Ashley Battarbee"]
# ["University of Alabama at Birmingham"]
# ["Owner"]
# ["Diana Thomas"]
# ["West Point, United States Military Academy"]
# ["Owner"]
# ["Jing Wang"]
# ["University of Texas at Arlington"]
# ["Owner", "Senior Researcher"]
# ["Susan Persky"]
# ["National Human Genome Research Institute (NIH-NHGRI)"]
#  ["Tze-Woei Tan", "Chiu-Hsieh Hsu"]
#  ["Owner", "Mid-career Tenured Researcher", "Late Career Tenured Researcher"]
#  ["University of Arizona", "University of Arizona"]
# ["Owner", "Graduate Trainee", "Graduate Trainee"]
# ["Mehak Gupta", "Raphael Poulain"]
# ["University of Delaware", "University of Delaware"]
# ["Owner"]
# ["Keri Hurley"]
# ["University of California, Irvine"]
# ["Owner"]
# ["Nayyar Ahmed"]
# ["University of Pittsburgh"]
# ["Owner", "Research Fellow"]
# ["Douglas Arneson"]
# ["University of California, San Francisco"]
# ["Owner", "Research Fellow"]
# ["Sara Taylor"]
# ["Massachusetts Institute of Technology"]
# ["Owner"]
# ["Hao Ma"]
# ["Tulane University"]
#                                                Roles  \
# 0                           [Owner, Research Fellow]
# 1         [Owner, Graduate Trainee, Research Fellow]
# 2                              [Owner, Collaborator]
# 3  [Robin Beaumont, Michael Weedon, Gareth Hawkes...
# 4                         [Owner, Project Personnel]
#
#                                          Researchers  \
# 0                                     [Sarada Ghosh]
# 1                              [Xinyi Tan, Jay Lusk]
# 2                     [Reagan Ballard, Micah Hysong]
# 3  [Research Fellow, Senior Researcher, Research ...
# 4                                        [Yuji Choi]
#
#                                         Institutions
# 0                               [Cornell University]
# 1             [Columbia University, Duke University]
# 2  [University of North Carolina, Chapel Hill, Un...
# 3  [University of Exeter, University of Exeter, U...
# 4                         [Johns Hopkins University]

# %%
unique_individuals = set()
unique_institutions = set()
total_individual_count = 0
multi_institutional_projects_count = 0


for result in parsed_results:
    researchers = result['Researchers']
    institutions = result['Institutions']


    unique_individuals.update(researchers)
    unique_institutions.update(institutions)
    total_individual_count += len(researchers)


    if len(set(institutions)) > 1:
        multi_institutional_projects_count += 1


average_individuals_per_team = total_individual_count / len(parsed_results)
percent_multi_institutional_teams = (multi_institutional_projects_count / len(parsed_results)) * 100

print(f"Average number of individuals per team: {average_individuals_per_team:.2f}")
print(f"# of unique individuals listed as team-members: {len(unique_individuals)}")
print(f"# of unique institutions: {len(unique_institutions)}")
print(f"% projects with multi-institutional teams: {percent_multi_institutional_teams:.2f}%")
# Out:
# Average number of individuals per team: 1.91
# # of unique individuals listed as team-members: 600
# # of unique institutions: 176
# % projects with multi-institutional teams: 15.48%

# %%
df_parsed = pd.read_csv('parsed_results.csv', converters={
    'Researchers': ast.literal_eval,
    'Institutions': ast.literal_eval
})


df_parsed['Individuals Per Team'] = df_parsed['Researchers'].apply(len)
df_parsed['Unique Individuals Per Entry'] = df_parsed['Researchers'].apply(lambda x: len(set(x)))
df_parsed['Unique Institutions Per Entry'] = df_parsed['Institutions'].apply(lambda x: len(set(x)))
df_parsed['Is Multi-Institutional'] = df_parsed['Institutions'].apply(lambda x: len(set(x)) > 1)
df_parsed.to_csv('qa_metrics_per_entry.csv', index=False)

# %%
df_extracted = pd.read_csv('extracted_team_info_sample.csv')
df_parsed = pd.read_csv('parsed_results.csv')
df_qa_metrics = pd.read_csv('qa_metrics_per_entry.csv')


df_combined = pd.concat([df_extracted, df_parsed, df_qa_metrics], axis=1)


df_combined.to_csv('combined_data.csv', index=False)
